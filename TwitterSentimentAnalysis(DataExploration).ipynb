# %% [markdown]
# <a href="https://colab.research.google.com/github/disha2sinha/BASICS-OF-PROGRAMMING/blob/master/TwitterSentimentAnalysis(DataExploration).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Import Dataset as PANDAS Dataframe**

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Out:
#      |████████████████████████████████| 993kB 2.9MB/s
# ...

# %%
auth.authenticate_user()
gauth=GoogleAuth()
gauth.credentials=GoogleCredentials.get_application_default()
drive=GoogleDrive(gauth)

# %%
link='https://drive.google.com/open?id=15tIM6B4Up-2qFFfRUeC7N7turErE42S_'

# %%
fluff,id=link.split('=')
print(id)
# Out:
# 15tIM6B4Up-2qFFfRUeC7N7turErE42S_

# %%
import pandas as pd

# %%
download=drive.CreateFile({'id':id})
download.GetContentFile('twitter_sentiment_data.csv')

# %%
df=pd.read_csv('twitter_sentiment_data.csv',engine='python')
df.head()
# Out:
#    0  ...  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0  0  ...  is upset that he can't update his Facebook by ...
# 1  0  ...  @Kenichan I dived many times for the ball. Man...
# 2  0  ...    my whole body feels itchy and like its on fire
# 3  0  ...  @nationwideclass no, it's not behaving at all....
# 4  0  ...                      @Kwesidei not the whole crew
#
# [5 rows x 6 columns]

# %%
df.rename(columns={'0':'Target','1467810369':'ID','Mon Apr 06 22:19:45 PDT 2009':'Time_Info','NO_QUERY':'Query','_TheSpecialOne_':'UN',df.columns[5]:'Comments'},inplace=True)
df
# Out:
#          Target  ...                                           Comments
# 0             0  ...  is upset that he can't update his Facebook by ...
# 1             0  ...  @Kenichan I dived many times for the ball. Man...
# 2             0  ...    my whole body feels itchy and like its on fire
# 3             0  ...  @nationwideclass no, it's not behaving at all....
# 4             0  ...                      @Kwesidei not the whole crew
# 5             0  ...                                        Need a hug
# 6             0  ...  @LOLTrish hey  long time no see! Yes.. Rains a...
# 7             0  ...               @Tatiana_K nope they didn't have it
# 8             0  ...                          @twittera que me muera ?
# 9             0  ...        spring break in plain city... it's snowing
# 10            0  ...                         I just re-pierced my ears
# 11            0  ...  @caregiving I couldn't bear to watch it.  And ...
# ...

# %% [markdown]
# **Data Description**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599999 entries, 0 to 1599998
# Data columns (total 6 columns):
# Target       1599999 non-null int64
# ID           1599999 non-null int64
# Time_Info    1599999 non-null object
# Query        1599999 non-null object
# UN           1599999 non-null object
# Comments     1599999 non-null object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df.describe()
# Out:
#              Target            ID
# count  1.599999e+06  1.599999e+06
# mean   2.000001e+00  1.998818e+09
# std    2.000001e+00  1.935757e+08
# min    0.000000e+00  1.467811e+09
# 25%    0.000000e+00  1.956916e+09
# 50%    4.000000e+00  2.002102e+09
# 75%    4.000000e+00  2.177059e+09
# max    4.000000e+00  2.329206e+09
